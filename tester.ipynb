# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler

# %%
dataz = pd.read_csv('model/data/cleaned-data.csv')

# %%
dataz
# Out:
#        zip_code       commune         province  type_of_property  \
# 0          2600     Antwerpen        Antwerpen                 0
# 1          2100     Antwerpen        Antwerpen                 0
# 2          2660     Antwerpen        Antwerpen                 0
# 3          1180         Uccle        Bruxelles                 0
# 4          2018     Antwerpen        Antwerpen                 0
# ...         ...           ...              ...               ...
# 26101      1130     Bruxelles        Bruxelles                 1
# 26102      1130     Bruxelles        Bruxelles                 1
# 26103      1130     Bruxelles        Bruxelles                 1
# 26104      8300  Knokke-Heist  West-Vlaanderen                 1
# 26105      8300  Knokke-Heist  West-Vlaanderen                 1
#
#       subtype_of_property      price building_condition  facade_number  \
# 0               apartment   149000.0               good            2.0
# 1               apartment   248000.0               good            2.0
# 2               apartment   229000.0               good            2.0
# 3               apartment   470000.0               good            2.0
# 4               apartment   480000.0               good            2.0
# ...                   ...        ...                ...            ...
# 26101               house   496000.0            no info            2.0
# 26102               house   506000.0            no info            2.0
# 26103               house   521000.0            no info            2.0
# 26104               house  1150000.0               good            3.0
# 26105               house  1225000.0               good            2.0
#
#        living_area equipped_kitchen  bedroom_nr  swimming_pool  furnished  \
# 0               48        installed           1              0          0
# 1               91        installed           3              0          0
# 2              100    not installed           3              0          0
# 3              179         equipped           3              0          0
# 4              116        installed           2              0          0
# ...            ...              ...         ...            ...        ...
# 26101          157         equipped           4              0          0
# 26102          156         equipped           4              0          0
# 26103          156         equipped           4              0          0
# 26104          204    not installed           3              0          0
# 26105          260    not installed           4              0          0
#
#        open_fire  terrace  garden  plot_surface sub_property_group_encoded
# 0              0      9.0       0             0                 apartments
# 1              0      2.0       0             0                 apartments
# 2              0     26.0       0             0                 apartments
# 3              0     10.0       0             0                 apartments
# 4              0      7.0       0             0                 apartments
# ...          ...      ...     ...           ...                        ...
# 26101          0      0.0      46             0                     houses
# 26102          0      0.0     103             0                     houses
# 26103          0      0.0     103             0                     houses
# 26104          0     12.0       0           311                     houses
# 26105          0     21.0       0           335                     houses
#
# [26106 rows x 18 columns]

# %%
dataz.iloc[[1],:].to_csv('test.csv', index=False)

# %%
scaler = MinMaxScaler(feature_range=(0,1))

# %%
socecon = pd.read_csv('model/data/soceconvert.csv')

# %%
processed = pd.merge(dataz, socecon.drop(columns=['refnis', 'province', 'commune']), on='zip_code', how='left')
processed.drop(columns=['zip_code', 'commune', 'facade_number', 'furnished', 'open_fire', 'sub_property_group_encoded', 'price'], inplace=True)

type_of_property_mapping = {'service flat': 1, 'flat studio': 1, 'chalet': 1, 'kot': 1, 'house': 2, 'apartment': 2, 'ground floor': 2, 'town house': 2, 'bungalow': 2, 
                    'duplex': 3, 'apartment block': 3, 'triplex': 3, 'farmhouse': 3, 'country cottage': 3, 'mixed use building': 3, 'manor house': 4, 'exceptional property': 4, 'villa': 4, 'penthouse': 4, 'mansion': 4, 'loft': 4}

province_mapping = {
    'Bruxelles': 11,
    'West-Vlaanderen': 10,
    'Vlaams Brabant': 9,    
    'Brabant Wallon': 8,
    'Antwerpen': 7,    
    'Oost-Vlaanderen': 6,
    'Limburg': 5,
    'Luxembourg': 4,
    'Namur': 3,
    'Liège': 2,
    'Hainaut': 1
    }

building_condition_mapping = {
    'good': 3,
    'no info': 2,
    'to renovate': 1,
    'to restore': 0
    }

kitchen_mapping = {
        'equipped': 2,
        'installed': 1,
        'not installed': 0
    }

processed['subtype_of_property'] = processed['subtype_of_property'].map(type_of_property_mapping)
processed['province'] = processed['province'].map(province_mapping)
processed['building_condition'] = processed['building_condition'].map(building_condition_mapping)
processed['equipped_kitchen'] = processed['equipped_kitchen'].map(kitchen_mapping)

# %%
processed.head()
# Out:
#    province  type_of_property  subtype_of_property  building_condition  \
# 0         7                 0                  2.0                   3
# 1         7                 0                  2.0                   3
# 2         7                 0                  2.0                   3
# 3        11                 0                  2.0                   3
# 4         7                 0                  2.0                   3
#
#    living_area  equipped_kitchen  bedroom_nr  swimming_pool  terrace  garden  \
# 0           48                 1           1              0      9.0       0
# 1           91                 1           3              0      2.0       0
# 2          100                 0           3              0     26.0       0
# 3          179                 2           3              0     10.0       0
# 4          116                 1           2              0      7.0       0
#
#    plot_surface  pop_dens  income_1y  income_17y
# 0             0      2666   19091.86    15580.68
# 1             0      2666   19091.86    15580.68
# 2             0      2666   19091.86    15580.68
# 3             0      3794   24200.73    19236.10
# 4             0      2666   19091.86    15580.68

# %%
scaled = scaler.fit_transform(processed)

# %%
scaled[1]
# Out:
# array([6.00000000e-01, 0.00000000e+00, 3.33333333e-01, 1.00000000e+00,
#        8.71327254e-02, 5.00000000e-01, 1.20000000e-01, 0.00000000e+00,
#        5.33475593e-04, 0.00000000e+00, 0.00000000e+00, 1.14130200e-01,
#        3.40468586e-01, 3.67362025e-01])

# %%
type_of_property_mapping = {'service flat': 1, 'flat studio': 1, 'chalet': 1, 'kot': 1, 'house': 2, 'apartment': 2, 'ground floor': 2, 'town house': 2, 'bungalow': 2, 
                        'duplex': 3, 'apartment block': 3, 'triplex': 3, 'farmhouse': 3, 'country cottage': 3, 'mixed use building': 3, 'manor house': 4, 'exceptional property': 4, 'villa': 4, 'penthouse': 4, 'mansion': 4, 'loft': 4}

# %%
print([x for x in type_of_property_mapping])
# Out:
# ['service flat', 'flat studio', 'chalet', 'kot', 'house', 'apartment', 'ground floor', 'town house', 'bungalow', 'duplex', 'apartment block', 'triplex', 'farmhouse', 'country cottage', 'mixed use building', 'manor house', 'exceptional property', 'villa', 'penthouse', 'mansion', 'loft']
